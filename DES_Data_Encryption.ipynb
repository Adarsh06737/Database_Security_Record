# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh06737/Database_Security_Record/blob/main/DES_Data_Encryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Crypto.Cipher import DES
from Crypto.Util.Padding import pad, unpad

# Key must be 8 bytes
key = b'12345678'

# Message
plain_text = input("Enter message: ").encode()

# Encrypt
cipher = DES.new(key, DES.MODE_ECB)
encrypted = cipher.encrypt(pad(plain_text, DES.block_size))
print("Encrypted (hex):", encrypted.hex())

# Decrypt
cipher = DES.new(key, DES.MODE_ECB)
decrypted = unpad(cipher.decrypt(encrypted), DES.block_size)
print("Decrypted:", decrypted.decode())
# Out:
# Enter message: Hi! you got a lottery of 1crore please click this link   http://fake_fraud.com
# Encrypted (hex): e18a088a3a7de3f69d76158a42db3a0412ebf8f35941fd9906259961cc1f4b647ab4b4a28e96d95ba2aff5e0c4c8756ca18809e0884aca4f97f9717086a353cba5383f3e6a877d2aa6e1e1e7dd1ce263
# Decrypted: Hi! you got a lottery of 1crore please click this link   http://fake_fraud.com
