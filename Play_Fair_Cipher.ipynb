# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh06737/Database_Security_Record/blob/main/Play_Fair_Cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
key = input("Key: ").upper().replace("J","I")
text = input("Text: ").upper().replace("J","I").replace(" ","")

# make key matrix
m = []
for c in key:
    if c not in m and c.isalpha(): m.append(c)
for c in "ABCDEFGHIKLMNOPQRSTUVWXYZ":
    if c not in m: m.append(c)
M = [m[i*5:(i+1)*5] for i in range(5)]

# make pairs
pairs = []
i=0
while i<len(text):
    a = text[i]
    b = text[i+1] if i+1<len(text) else "X"
    if a==b: pairs.append(a+"X"); i+=1
    else: pairs.append(a+b); i+=2

# encrypt
cipher=""
for a,b in pairs:
    for r in range(5):
        for c in range(5):
            if M[r][c]==a: r1,c1=r,c
            if M[r][c]==b: r2,c2=r,c
    if r1==r2: cipher+=M[r1][(c1+1)%5]+M[r2][(c2+1)%5]
    elif c1==c2: cipher+=M[(r1+1)%5][c1]+M[(r2+1)%5][c2]
    else: cipher+=M[r1][c2]+M[r2][c1]

print("Cipher:", cipher)
# Out:
# Key: adarsh
# Text: adarsh
# Cipher: DRDSHA
