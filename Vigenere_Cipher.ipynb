# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh06737/Database_Security_Record/blob/main/Vigenere_Cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
def encipher():
    input_text = input("\n\nEnter Plain Text: ")
    key = input("\nEnter Key Value: ")
    print("\nResultant Cipher Text: ", end="")
    j = 0
    for i in range(len(input_text)):
        if j >= len(key):
            j = 0
        cipher_char = chr(65 + ((ord(input_text[i].upper()) - 65 + ord(key[j].upper()) - 65) % 26))
        print(cipher_char, end="")
        j += 1
    print()

def decipher():
    input_text = input("\n\nEnter Cipher Text: ")
    key = input("\n\nEnter the key value: ")
    j = 0
    for i in range(len(input_text)):
        if j >= len(key):
            j = 0
        value = (ord(input_text[i].upper()) - 64) - (ord(key[j].upper()) - 64)
        if value < 0:
            value = value + 26 # Corrected decryption logic
        print(chr(65 + (value % 26)), end="")
        j += 1
    print()

def main():
    while True:
        print("\n1. Encrypt Text")
        print("\t2. Decrypt Text")
        print("\t3. Exit")
        try:
            choice = int(input("\n\nEnter Your Choice: "))
            if choice == 3:
                break
            elif choice == 1:
                encipher()
            elif choice == 2:
                decipher()
            else:
                print("Please Enter Valid Option.")
        except ValueError:
            print("Invalid input. Please enter a number (1, 2, or 3).")


if __name__ == "__main__":
    main()
# Out:
# 1. Encrypt Text
# 	2. Decrypt Text
# 	3. Exit
#
#
# Enter Your Choice: 1
#
#
# Enter Plain Text: adarsh
#
# Enter Key Value: 2
#
# Resultant Cipher Text: LOLCDS
#
# 1. Encrypt Text
# 	2. Decrypt Text
# 	3. Exit
#
#
# Enter Your Choice: 2
#
#
# Enter Cipher Text: LOLCDS
#
#
# Enter the key value: 2
# ADARSH
#
# 1. Encrypt Text
# 	2. Decrypt Text
# 	3. Exit
#
#
# Enter Your Choice: 3
